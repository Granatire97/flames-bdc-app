# %%
import pandas as pd

df = pd.read_csv("/Users/markgranatire/Documents/flames-bdc-app/data/files/olympic_womens_dataset.csv")
df.head()
print(df.columns.tolist())

df = df.drop(["Clock", "Home Team Goals", "Away Team Goals", "X Coordinate 2", "Y Coordinate 2"], axis=1)
df['game_date'] = pd.to_datetime(df['game_date'])
df.head()
# Out:
# ['game_date', 'Home Team', 'Away Team', 'Period', 'Clock', 'Home Team Skaters', 'Away Team Skaters', 'Home Team Goals', 'Away Team Goals', 'Team', 'Player', 'Event', 'X Coordinate', 'Y Coordinate', 'Detail 1', 'Detail 2', 'Detail 3', 'Detail 4', 'Player 2', 'X Coordinate 2', 'Y Coordinate 2']
#    game_date                 Home Team  \
# 0 2018-02-11  Olympic (Women) - Canada
# 1 2018-02-11  Olympic (Women) - Canada
# 2 2018-02-11  Olympic (Women) - Canada
# 3 2018-02-11  Olympic (Women) - Canada
# 4 2018-02-11  Olympic (Women) - Canada
#
#                                         Away Team  Period  Home Team Skaters  \
# 0  Olympic (Women) - Olympic Athletes from Russia       1                  5
# 1  Olympic (Women) - Olympic Athletes from Russia       1                  5
# 2  Olympic (Women) - Olympic Athletes from Russia       1                  5
# 3  Olympic (Women) - Olympic Athletes from Russia       1                  5
# 4  Olympic (Women) - Olympic Athletes from Russia       1                  5
#
#    Away Team Skaters                      Team             Player  \
# 0                  5  Olympic (Women) - Canada        Emily Clark
# 1                  5  Olympic (Women) - Canada  Meaghan Mikkelson
# 2                  5  Olympic (Women) - Canada  Meaghan Mikkelson
# 3                  5  Olympic (Women) - Canada  Meaghan Mikkelson
# 4                  5  Olympic (Women) - Canada        Sarah Nurse
#
#            Event  X Coordinate  Y Coordinate  Detail 1 Detail 2 Detail 3  \
# 0    Faceoff Win           100            42  Backhand      NaN      NaN
# 1  Puck Recovery            91            67       NaN      NaN      NaN
# 2    Dump In/Out           106            81  Retained      NaN      NaN
# 3     Zone Entry           106            81    Dumped      NaN      NaN
# 4  Puck Recovery           168             1       NaN      NaN      NaN
#
#   Detail 4            Player 2
# 0      NaN  Lyudmila Belyakova
# 1      NaN                 NaN
# 2      NaN                 NaN
# 3      NaN      Liana Ganeyeva
# 4      NaN                 NaN

# %%
player_names = df["Player"].unique()
print(player_names)
# Out:
# ['Emily Clark' 'Meaghan Mikkelson' 'Sarah Nurse' 'Lyudmila Belyakova'
#  'Maria Batalova' 'Olga Sosina' 'Valeria Pavlova' 'Laura Stacey'
#  'Marie-Philip Poulin' 'Renata Fast' 'Melodie Daoust' 'Yelena Dergachyova'
#  'Anna Shokhina' 'Meghan Agosta' 'Yekaterina Nikolayeva'
#  'Brigette Lacquette' 'Angelina Goncharenko' 'Liana Ganeyeva'
#  'Haley Irwin' 'Rebecca Johnston' 'Laura Fortino' 'Brianne Jenner'
#  'Yevgenia Dyupina' 'Yekaterina Smolina' 'Natalie Spooner'
#  'Nadezhda Morozova' 'Ann-Renee Desbiens' 'Jocelyne Larocque'
#  'Fanuza Kadirova' 'Bailey Bram' 'Lauriane Rougeau' 'Nina Pirogova'
#  'Jillian Saulnier' 'Yekaterina Lovova' 'Jennifer Wakefield'
#  'Alevtina Shtaryova' 'Blayre Turnbull' 'Nadezhda Alexandrova'
#  'Alyona Starovoitova' 'Diana Kanayeva' 'Svetlana Tkachyova' 'Isa Rahunen'
#  'Minnamari Tuominen' 'Venla Hovi' 'Ronja Savolainen' 'Rosa Lindstedt'
#  'Linda Valimaki' 'Jenni Hiirikoski' 'Annina Rajahuhta' 'Sanni Hakala'
#  'Emma Nuutinen' 'Noora Tulus' 'Tanja Niskanen' 'Mira Jalosuo'
#  'Susanna Tapani' 'Riikka Sallinen' 'Michelle Karvinen' 'Shannon Szabados'
#  'Petra Nieminen' 'Noora Raty' 'Sara Sakkinen' 'Saila Saari'
#  'Dani Cameranesi' 'Brianna Decker' 'Megan Keller' 'Emily Pfalzer'
#  'Kendall Coyne Schofield' 'Hannah Brandt' 'Kali Flanagan' 'Kelly Pannek'
#  'Sidney Morin' 'Lee Stecklein' 'Monique Lamoureux' 'Meghan Duggan'
#  'Amanda Pelkey' 'Gigi Marvin' 'Cayla Barnes' 'Maddie Rooney'
#  'Kacey Bellamy' 'Hilary Knight' 'Amanda Kessel' 'Jocelyne Lamoureux'
#  'Haley Skarupa' 'Genevieve Lacasse' 'Viktoria Kulishova'
#  'Valeria Tarakanova' 'Yekaterina Likhachyova' 'Kayla Nielsen'
#  'Justine Reyes' 'Ella Shelton' 'Skylar Podvey' 'Cassidy Vinkle'
#  'Taylar Cianfarano' 'Taylor Turnquist' 'Rachael Smith' 'Kelly Mariani'
#  'Kalie Grant' 'Loren Gabel' 'Kassidy Sauve' 'Jacquie Diffley'
#  'Nadine Edney' 'Maggie McLaughlin' 'Steph Keryluk' 'Josiane Pozzebon'
#  'Michala Pejzlova' 'Elizabeth Giguere' 'Taylor Sawka' 'Emma Keenan'
#  'Lydia Grauer' 'Morgan Helgeson' 'Kristy Pidgeon' 'Amanda Butterfield'
#  'Avery Mitchell' 'Charlea Pedersen' 'Tia Stoddard' 'Jessica Poirier'
#  'Claire Dudley' 'Kristen Guerriero' 'Grace Harrison' 'Natalie Wozney'
#  'Sonjia Shelly' 'Stephanie Voge' 'Brittany Howard' 'Alex Cavalini'
#  'Megan Bozek' 'Rebecca Leslie' 'Erin Ambrose' 'Halli Krzyzaniak'
#  'Savannah Harmon' 'Hayley Scamurra' 'Jamie Lee Rattray'
#  'Emerance Maschmeyer' 'Dana Trivigno' 'Alex Carpenter' 'Zoe Hickel'
#  'Shelly Picard' 'Ann-Sophie Bettez' 'Victoria Bach' 'Kaitlin Burt'
#  'Katelyn Gosling' 'Annie Pankowski' 'Jesse Compher' 'Mich Zandee-Hart'
#  'Melissa Samoskevich' 'Jamie Bourbonnais' 'Sydney Brodt' 'Nelli Laitinen'
#  'Elisa Holopainen' 'Viivi Vainikka' 'Ella Viitasuo']
